# %%
import pennylane as qml
from pennylane import numpy as np
import jax
import jax.numpy as jnp
from jax import jit
from functools import partial

from matplotlib import pyplot as plt

import copy
import tqdm  # Pretty progress bars
import joblib  # Writing and loading

import sys
sys.path.insert(0, '../')
import vqe
import qcnn
import nnising_chain
import annni_model
import losses
import hamiltonians
import visualization as qplt
##############

# %%
N = 8
n_states = 100
J1 = 1

lr = 0.1
epochs = 10000
reg = 0

# %%
Hs = hamiltonians.hamiltonian(nnising_chain.build_Hs, N = N, n_states = n_states, J1 = J1)
myvqe = vqe.vqe(Hs, vqe.circuit_ising)

# %%
myvqe.train(lr, 10, circuit = True, recycle = True, reg = 0)
myvqe.train(lr, epochs, circuit = False, recycle = False, reg = reg, save_trajectories = True)
# Out:
# +--- CIRCUIT ---+
# 0: ──||──H─╭C──RY(0.00)──────────────────────────────────────────────────────────────||──H─╭C
# 1: ──||──H─╰X─╭C─────────RY(1.00)────────────────────────────────────────────────────||──H─╰X
# 2: ──||──H────╰X────────╭C─────────RY(2.00)──────────────────────────────────────────||──H───
# 3: ──||──H──────────────╰X────────╭C─────────RY(3.00)────────────────────────────────||──H───
# 4: ──||──H────────────────────────╰X────────╭C─────────RY(4.00)──────────────────────||──H───
# 5: ──||──H──────────────────────────────────╰X────────╭C─────────RY(5.00)────────────||──H───
# 6: ──||──H────────────────────────────────────────────╰X────────╭C─────────RY(6.00)──||──H───
# 7: ──||──H──────────────────────────────────────────────────────╰X─────────RY(7.00)──||──H───
#
# ───RY(8.00)───────────────────────────────────────────────────────────────────||──H─╭C──RY(16.00)
# ──╭C─────────RY(9.00)─────────────────────────────────────────────────────────||──H─╰X─╭C────────
# ──╰X────────╭C─────────RY(10.00)──────────────────────────────────────────────||──H────╰X────────
# ────────────╰X────────╭C──────────RY(11.00)───────────────────────────────────||──H──────────────
# ──────────────────────╰X─────────╭C──────────RY(12.00)────────────────────────||──H──────────────
# ─────────────────────────────────╰X─────────╭C──────────RY(13.00)─────────────||──H──────────────
# ────────────────────────────────────────────╰X─────────╭C──────────RY(14.00)──||──H──────────────
# ───────────────────────────────────────────────────────╰X──────────RY(15.00)──||──H──────────────
#
# ─────────────────────────────────────────────────────────────────────||──H─╭C──RY(24.00)───────────
# ───RY(17.00)─────────────────────────────────────────────────────────||──H─╰X─╭C──────────RY(25.00)
# ──╭C──────────RY(18.00)──────────────────────────────────────────────||──H────╰X─────────╭C────────
# ──╰X─────────╭C──────────RY(19.00)───────────────────────────────────||──H───────────────╰X────────
# ─────────────╰X─────────╭C──────────RY(20.00)────────────────────────||──H─────────────────────────
# ────────────────────────╰X─────────╭C──────────RY(21.00)─────────────||──H─────────────────────────
# ───────────────────────────────────╰X─────────╭C──────────RY(22.00)──||──H─────────────────────────
# ──────────────────────────────────────────────╰X──────────RY(23.00)──||──H─────────────────────────
#
# ──────────────────────────────────────────────────────────||──H─╭C──RY(32.00)──────────────────────
# ──────────────────────────────────────────────────────────||──H─╰X─╭C──────────RY(33.00)───────────
# ───RY(26.00)──────────────────────────────────────────────||──H────╰X─────────╭C──────────RY(34.00)
# ──╭C──────────RY(27.00)───────────────────────────────────||──H───────────────╰X─────────╭C────────
# ──╰X─────────╭C──────────RY(28.00)────────────────────────||──H──────────────────────────╰X────────
# ─────────────╰X─────────╭C──────────RY(29.00)─────────────||──H────────────────────────────────────
# ────────────────────────╰X─────────╭C──────────RY(30.00)──||──H────────────────────────────────────
# ───────────────────────────────────╰X──────────RY(31.00)──||──H────────────────────────────────────
#
# ───────────────────────────────────────────────||──H─╭C──RY(40.00)─────────────────────────────────
# ───────────────────────────────────────────────||──H─╰X─╭C──────────RY(41.00)──────────────────────
# ───────────────────────────────────────────────||──H────╰X─────────╭C──────────RY(42.00)───────────
# ───RY(35.00)───────────────────────────────────||──H───────────────╰X─────────╭C──────────RY(43.00)
# ──╭C──────────RY(36.00)────────────────────────||──H──────────────────────────╰X─────────╭C────────
# ──╰X─────────╭C──────────RY(37.00)─────────────||──H─────────────────────────────────────╰X────────
# ─────────────╰X─────────╭C──────────RY(38.00)──||──H───────────────────────────────────────────────
# ────────────────────────╰X──────────RY(39.00)──||──H───────────────────────────────────────────────
#
# ────────────────────────────────────||──RX(48.00)─┤  State
# ────────────────────────────────────||──RX(49.00)─┤  State
# ────────────────────────────────────||──RX(50.00)─┤  State
# ────────────────────────────────────||──RX(51.00)─┤  State
# ───RY(44.00)────────────────────────||──RX(52.00)─┤  State
# ──╭C──────────RY(45.00)─────────────||──RX(53.00)─┤  State
# ──╰X─────────╭C──────────RY(46.00)──||──RX(54.00)─┤  State
# ─────────────╰X──────────RY(47.00)──||──RX(55.00)─┤  State
# 100/100: 100%|██████████████████████████████████| 99/99 [00:21<00:00,  4.71it/s]
# Cost: 0.0000 | Mean F.: 0.5048: 100%|████| 10000/10000 [00:57<00:00, 174.30it/s]

# %%
qplt.show_VQE_nnisingchain(myvqe)

# %%
myqcnn = qcnn.qcnn(myvqe, qcnn.qcnn_circuit)
myqcnn.train(0.25, 2000, np.arange(100), losses.cross_entropy, circuit=False, plot=False)
# Out:
# Cost: 7.2402435762342066e-06: 100%|█████████| 2000/2000 [00:22<00:00, 89.37it/s]

# %%
qplt.show_QCNN_classification1D(myqcnn, inject = False)
